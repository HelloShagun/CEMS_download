# %%
import multi_flood_map_function as multi

#EMSR680_AOI01_DEL_PRODUCT_v2
#GFM - 20230805T165057_VV_EU020M_E051N012T3

# Define all your rasters in a dictionary
raster_maps = {
    "DLR": r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Products\GFM_EMSR680_AOI01_DEL_PRODUCT_v2\ENSEMBLE_FLOOD_20230805T165057_VV_EU020M_E051N012T3_gfm_bundle\ENSEMBLE_FLOOD_20230805T165057_VV_EU020M_E051N012T3__dlr_flood_extent.tif",
    "LIST": r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Products\GFM_EMSR680_AOI01_DEL_PRODUCT_v2\ENSEMBLE_FLOOD_20230805T165057_VV_EU020M_E051N012T3_gfm_bundle\ENSEMBLE_FLOOD_20230805T165057_VV_EU020M_E051N012T3__list_flood_extent.tif",
    "TUW": r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Products\GFM_EMSR680_AOI01_DEL_PRODUCT_v2\ENSEMBLE_FLOOD_20230805T165057_VV_EU020M_E051N012T3_gfm_bundle\ENSEMBLE_FLOOD_20230805T165057_VV_EU020M_E051N012T3__tuw_flood_extent.tif",
    "ENSEMBLE": r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Products\GFM_EMSR680_AOI01_DEL_PRODUCT_v2\ENSEMBLE_FLOOD_20230805T165057_VV_EU020M_E051N012T3_gfm_bundle\ENSEMBLE_FLOOD_20230805T165057_VV_EU020M_E051N012T3__ensemble_flood_extent.tif"
}

# Run the multi-raster workflow
all_metrics = multi.multi_raster_workflow(
    raster_paths_dict=raster_maps,
    shapefile1_path=r"C:\Users\Student\Documents\OFYP\flood\events\EMSR\Flood\EMSR680_AOI01_DEL_PRODUCT_v2\EMSR680_AOI01_DEL_PRODUCT_areaOfInterestA_v1.shp",
    shapefile2_path=r"C:\Users\Student\Documents\OFYP\flood\events\EMSR\Flood\EMSR680_AOI01_DEL_PRODUCT_v2\EMSR680_AOI01_DEL_PRODUCT_observedEventA_v2.shp",
    exclusion_path=r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Products\GFM_EMSR680_AOI01_DEL_PRODUCT_v2\ENSEMBLE_FLOOD_20230805T165057_VV_EU020M_E051N012T3_gfm_bundle\ENSEMBLE_FLOOD_20230805T165057_VV_EU020M_E051N012T3__exclusion_mask.tif",   # optional
    out_dir=r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Comparison\EMSR680_AOI01_DEL_PRODUCT_v2-GFM_20230805T165057_VV_EU020M_E051N012T3"
)
# Out:
# ...
# 📋 STEP 1: Processing Reference Data
# ...
#
# 🗺️  Using 'DLR' as reference for alignment...
#
# 🎯 Rasterizing ground truth shapefile...
#
# 🚫 Processing exclusion mask...
# ⚙️ Aligning and reprojecting exclusion mask to match reference raster...
# ✅ Exclusion mask ready
#
# ...
# 📋 STEP 2: Processing Individual Rasters
# ...
#
# ...
# 🗺️  Processing: DLR
# ...
#
# 📊 Evaluating DLR against ground truth...
# 🧭 Excluding 831449 pixels from evaluation.
#
# 📊 Total pixels in clipped extent: 2570757
# 📊 Pixels masked (nodata): 2163267
# 📊 Pixels excluded: 831449
# 📊 Pixels evaluated (valid): 407490
# ✅ Accuracy  : 0.9901
# ✅ Precision : 1.0000
# ✅ Recall    : 0.0394
# ✅ F1-score  : 0.0758
# ✅ DLR processing complete
#
# ...
# 🗺️  Processing: LIST
# ...
#
# 📊 Evaluating LIST against ground truth...
# 🧭 Excluding 831449 pixels from evaluation.
#
# 📊 Total pixels in clipped extent: 2570757
# 📊 Pixels masked (nodata): 2163267
# 📊 Pixels excluded: 831449
# 📊 Pixels evaluated (valid): 407490
# ✅ Accuracy  : 0.9904
# ...

# %%
import multi_flood_map_function as multi

#EMSR728 AOI04
#GFM 20240607T053455_VV_EU020M_E048N015T3

# Define all your rasters in a dictionary
raster_maps = {
    "DLR": r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Products\GFM_EMSR728_AOI04_DEL_MONIT04_v1\ENSEMBLE_FLOOD_20240607T053455_VV_EU020M_E048N015T3_gfm_bundle\ENSEMBLE_FLOOD_20240607T053455_VV_EU020M_E048N015T3__dlr_flood_extent.tif",
    "LIST": r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Products\GFM_EMSR728_AOI04_DEL_MONIT04_v1\ENSEMBLE_FLOOD_20240607T053455_VV_EU020M_E048N015T3_gfm_bundle\ENSEMBLE_FLOOD_20240607T053455_VV_EU020M_E048N015T3__list_flood_extent.tif",
    "TUW": r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Products\GFM_EMSR728_AOI04_DEL_MONIT04_v1\ENSEMBLE_FLOOD_20240607T053455_VV_EU020M_E048N015T3_gfm_bundle\ENSEMBLE_FLOOD_20240607T053455_VV_EU020M_E048N015T3__tuw_flood_extent.tif",
    "ENSEMBLE": r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Products\GFM_EMSR728_AOI04_DEL_MONIT04_v1\ENSEMBLE_FLOOD_20240607T053455_VV_EU020M_E048N015T3_gfm_bundle\ENSEMBLE_FLOOD_20240607T053455_VV_EU020M_E048N015T3__ensemble_flood_extent.tif"
}

# Run the multi-raster workflow
all_metrics = multi.multi_raster_workflow(
    raster_paths_dict=raster_maps,
    shapefile1_path=r"C:\Users\Student\Documents\OFYP\flood\events\EMSR\Flood\EMSR728_AOI04_DEL_MONIT04_v1\EMSR728_AOI04_DEL_MONIT04_areaOfInterestA_v1.shp",
    shapefile2_path=r"C:\Users\Student\Documents\OFYP\flood\events\EMSR\Flood\EMSR728_AOI04_DEL_MONIT04_v1\EMSR728_AOI04_DEL_MONIT04_observedEventA_v1.shp",
    exclusion_path=r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Products\GFM_EMSR728_AOI04_DEL_MONIT04_v1\ENSEMBLE_FLOOD_20240607T053455_VV_EU020M_E048N015T3_gfm_bundle\ENSEMBLE_FLOOD_20240607T053455_VV_EU020M_E048N015T3__exclusion_mask.tif",   # optional
    out_dir=r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Comparison\EMSR728_AOI04_DEL_MONIT04_v1-GFM_20240607T053455_VV_EU020M_E048N015T3"
)
# Out:
# ...
# 📋 STEP 1: Processing Reference Data
# ...
#
# 🗺️  Using 'DLR' as reference for alignment...
#
# 🎯 Rasterizing ground truth shapefile...
#
# 🚫 Processing exclusion mask...
# ⚙️ Aligning and reprojecting exclusion mask to match reference raster...
# ✅ Exclusion mask ready
#
# ...
# 📋 STEP 2: Processing Individual Rasters
# ...
#
# ...
# 🗺️  Processing: DLR
# ...
#
# 📊 Evaluating DLR against ground truth...
# 🧭 Excluding 975367 pixels from evaluation.
#
# 📊 Total pixels in clipped extent: 13419788
# 📊 Pixels masked (nodata): 12008982
# 📊 Pixels excluded: 975367
# 📊 Pixels evaluated (valid): 1410806
# ✅ Accuracy  : 0.9923
# ✅ Precision : 0.8205
# ✅ Recall    : 0.6803
# ✅ F1-score  : 0.7438
# ✅ DLR processing complete
#
# ...
# 🗺️  Processing: LIST
# ...
#
# 📊 Evaluating LIST against ground truth...
# 🧭 Excluding 975367 pixels from evaluation.
#
# 📊 Total pixels in clipped extent: 13419788
# 📊 Pixels masked (nodata): 12009383
# 📊 Pixels excluded: 975367
# 📊 Pixels evaluated (valid): 1410405
# ✅ Accuracy  : 0.9929
# ...

# %%
import multi_flood_map_function as multi

#EMSR789 AOI01
#GFM 20250308T110125_VV_SA020M_E048N069T3

# Define all your rasters in a dictionary
raster_maps = {
    "DLR": r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Products\GFM_EMSR789_AOI01_DEL_MONIT05_v1\ENSEMBLE_FLOOD_20250308T110125_VV_SA020M_E048N069T3_gfm_bundle\ENSEMBLE_FLOOD_20250308T110125_VV_SA020M_E048N069T3__dlr_flood_extent.tif",
    "LIST": r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Products\GFM_EMSR789_AOI01_DEL_MONIT05_v1\ENSEMBLE_FLOOD_20250308T110125_VV_SA020M_E048N069T3_gfm_bundle\ENSEMBLE_FLOOD_20250308T110125_VV_SA020M_E048N069T3__list_flood_extent.tif",
    "TUW": r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Products\GFM_EMSR789_AOI01_DEL_MONIT05_v1\ENSEMBLE_FLOOD_20250308T110125_VV_SA020M_E048N069T3_gfm_bundle\ENSEMBLE_FLOOD_20250308T110125_VV_SA020M_E048N069T3__tuw_flood_extent.tif",
    "ENSEMBLE": r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Products\GFM_EMSR789_AOI01_DEL_MONIT05_v1\ENSEMBLE_FLOOD_20250308T110125_VV_SA020M_E048N069T3_gfm_bundle\ENSEMBLE_FLOOD_20250308T110125_VV_SA020M_E048N069T3__ensemble_flood_extent.tif"
}

# Run the multi-raster workflow
all_metrics = multi.multi_raster_workflow(
    raster_paths_dict=raster_maps,
    shapefile1_path=r"C:\Users\Student\Documents\OFYP\flood\events\EMSR\Flood\EMSR789_AOI01_DEL_MONIT05_v1\EMSR789_AOI01_DEL_MONIT05_areaOfInterestA_v1.shp",
    shapefile2_path=r"C:\Users\Student\Documents\OFYP\flood\events\EMSR\Flood\EMSR789_AOI01_DEL_MONIT05_v1\EMSR789_AOI01_DEL_MONIT05_observedEventA_v1.shp",
    exclusion_path=r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Products\GFM_EMSR789_AOI01_DEL_MONIT05_v1\ENSEMBLE_FLOOD_20250308T110125_VV_SA020M_E048N069T3_gfm_bundle\ENSEMBLE_FLOOD_20250308T110125_VV_SA020M_E048N069T3__exclusion_mask.tif",   # optional
    out_dir=r"C:\Users\Student\Documents\OFYP\flood\events\GFM\Comparison\EMSR789_AOI01_DEL_MONIT05_v1-GFM_20250308T110125_VV_SA020M_E048N069T3"
)
# Out:
# ...
# 📋 STEP 1: Processing Reference Data
# ...
#
# 🗺️  Using 'DLR' as reference for alignment...
#
# 🎯 Rasterizing ground truth shapefile...
#
# 🚫 Processing exclusion mask...
# ⚙️ Aligning and reprojecting exclusion mask to match reference raster...
# ✅ Exclusion mask ready
#
# ...
# 📋 STEP 2: Processing Individual Rasters
# ...
#
# ...
# 🗺️  Processing: DLR
# ...
#
# 📊 Evaluating DLR against ground truth...
# 🧭 Excluding 573413 pixels from evaluation.
#
# 📊 Total pixels in clipped extent: 1279719
# 📊 Pixels masked (nodata): 1074930
# 📊 Pixels excluded: 573413
# 📊 Pixels evaluated (valid): 204789
# ✅ Accuracy  : 0.9432
# ✅ Precision : 0.6570
# ✅ Recall    : 0.3429
# ✅ F1-score  : 0.4507
# ✅ DLR processing complete
#
# ...
# 🗺️  Processing: LIST
# ...
#
# 📊 Evaluating LIST against ground truth...
# 🧭 Excluding 573413 pixels from evaluation.
#
# 📊 Total pixels in clipped extent: 1279719
# 📊 Pixels masked (nodata): 1074930
# 📊 Pixels excluded: 573413
# 📊 Pixels evaluated (valid): 204789
# ✅ Accuracy  : 0.9596
# ...
